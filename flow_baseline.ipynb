# %%
"""Runs the environments located in flow/benchmarks.

The environment file can be modified in the imports to change the environment
this runner script is executed on. This file runs the PPO algorithm in rllib
and utilizes the hyper-parameters specified in:
Proximal Policy Optimization Algorithms by Schulman et. al.
"""
import os
import json
import argparse

import ray
import ray.tune as tune
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from algorithms.envs.flow.utils.registry import make_create_env
from algorithms.envs.flow.utils.rllib import FlowParamsEncoder

# %%
benchmark_name = 'grid0'
# number of rollouts per training iteration
num_rollouts = 1
# number of parallel workers
num_cpus = 1
# Import the benchmark and fetch its flow_params
benchmark = __import__(
    "algorithms.envs.flow.benchmarks.%s" % benchmark_name, fromlist=["flow_params"])
flow_params = benchmark.flow_params
flow_params['env'].evaluate = True

# get the env name and a creator for the environment
create_env, env_name = make_create_env(params=flow_params, version=0)

# initialize a ray instance
ray.init()

alg_run = "PPO"

horizon = flow_params["env"].horizon
agent_cls = get_agent_class(alg_run)
config = agent_cls._default_config.copy()
config["num_workers"] = min(num_cpus, num_rollouts)
config["train_batch_size"] = horizon * num_rollouts
config["use_gae"] = True
config["horizon"] = horizon
gae_lambda = 0.97
step_size = 5e-4
if benchmark_name == "grid0":
    gae_lambda = 0.5
    step_size = 5e-5
elif benchmark_name == "grid1":
    gae_lambda = 0.3
config["lambda"] = gae_lambda
config["lr"] = step_size
config["vf_clip_param"] = 1e6
config["num_sgd_iter"] = 10
config['clip_actions'] = False  # FIXME(ev) temporary ray bug
config["model"]["fcnet_hiddens"] = [100, 50, 25]
config["observation_filter"] = "NoFilter"

# save the flow params for replay
flow_json = json.dumps(
    flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
config['env_config']['flow_params'] = flow_json
config['env_config']['run'] = alg_run

# Register as rllib env
register_env(env_name, create_env)
# Out:
# 2021-09-07 05:08:07,230	WARNING utils.py:518 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# /root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/services.py:238: UserWarning: Not all Ray Dashboard dependencies were found. To use the dashboard please install Ray using `pip install ray[default]`. To disable this message, set RAY_DISABLE_IMPORT_WARNING env var to '1'.
#   warnings.warn(warning_message)
# 2021-09-07 05:08:09,840	WARNING deprecation.py:39 -- DeprecationWarning: `get_agent_class` has been deprecated. Use `get_trainer_class` instead. This will raise an error in the future!

# %%
base_dir = '/root/ray_results/grid_0/'
dir_ls = os.listdir(base_dir)
subdir = []
for direc in dir_ls:
    if str.find(direc, '.') == -1 and str.find(direc, '08-30') != -1:
        subdir.append(direc)
print(subdir)

subdir = [base_dir + direc for direc in subdir]
# Out:
# ['PPO_TrafficLightGridBenchmarkEnv-v0_e3367_00000_0_2021-08-30_18-12-50', 'PPO_TrafficLightGridBenchmarkEnv-v0_e3367_00001_1_2021-08-30_18-12-50', 'PPO_TrafficLightGridBenchmarkEnv-v0_e3367_00002_2_2021-08-30_18-12-50', 'PPO_TrafficLightGridBenchmarkEnv-v0_f4028_00000_0_2021-08-30_18-13-19', 'PPO_TrafficLightGridBenchmarkEnv-v0_f4028_00001_1_2021-08-30_18-13-19', 'PPO_TrafficLightGridBenchmarkEnv-v0_f4028_00002_2_2021-08-30_18-13-19', 'PPO_TrafficLightGridBenchmarkEnv-v0_02039_00000_0_2021-08-30_18-13-42', 'PPO_TrafficLightGridBenchmarkEnv-v0_02039_00001_1_2021-08-30_18-13-42', 'PPO_TrafficLightGridBenchmarkEnv-v0_02039_00002_2_2021-08-30_18-13-42']

# %%
results = []
exp_tag = {
    "run": alg_run,
    "env": env_name,
    "config": {
        **config
    },
    "max_failures": 999,
    "stop": {
        "training_iteration": 1
    },
}
for direc in subdir:
    test_result = {}
    dir_ls = os.listdir(direc)
    for sdir in dir_ls:
        if sdir.find('checkpoint') == 0:
            ckpt_base_dir = direc + '/{}'.format(sdir)
            iter = int(sdir[11:])
            exp_tag['restore'] = ckpt_base_dir + '/checkpoint-{}'.format(iter)
            trials = tune.run_experiments({
                flow_params["exp_tag"]: exp_tag
            })
            test_result[str(iter)] = trials
    results.append(test_result)
# Out:
# 2021-09-07 05:07:46,368	ERROR syncer.py:72 -- Log sync requires rsync to be installed.
# == Status ==<br>Memory usage on this node: 25.6/38.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2.0/8 CPUs, 0/0 GPUs, 0.0/7.85 GiB heap, 0.0/3.93 GiB objects<br>Result logdir: /root/ray_results/grid_0<br>Number of trials: 5/5 (4 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                     </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00000</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00001</td><td>PENDING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00002</td><td>PENDING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00003</td><td>PENDING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00004</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=89057) 2021-09-07 05:07:49,780	INFO trainer.py:714 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=89057) 2021-09-07 05:07:49,780	INFO ppo.py:159 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (pid=89057) 2021-09-07 05:07:49,781	INFO trainer.py:728 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=89047) 2021-09-07 05:07:49,882	INFO trainer.py:714 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=89047) 2021-09-07 05:07:49,883	INFO ppo.py:159 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (pid=89047) 2021-09-07 05:07:49,883	INFO trainer.py:728 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=89060) 2021-09-07 05:07:50,106	INFO trainer.py:714 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=89060) 2021-09-07 05:07:50,106	INFO ppo.py:159 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (pid=89060) 2021-09-07 05:07:50,106	INFO trainer.py:728 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=89056) 2021-09-07 05:07:50,103	INFO trainer.py:714 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=89056) 2021-09-07 05:07:50,103	INFO ppo.py:159 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (pid=89056) 2021-09-07 05:07:50,103	INFO trainer.py:728 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# == Status ==<br>Memory usage on this node: 26.7/38.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8.0/8 CPUs, 0/0 GPUs, 0.0/7.85 GiB heap, 0.0/3.93 GiB objects<br>Result logdir: /root/ray_results/grid_0<br>Number of trials: 5/5 (1 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                     </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00000</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00001</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00002</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00003</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00004</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=89061) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89061) Instructions for updating:
# (pid=89061) If using Keras pass *_constraint arguments to layers.
# (pid=89061) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89061) Instructions for updating:
# (pid=89061) If using Keras pass *_constraint arguments to layers.
# (pid=89058) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89058) Instructions for updating:
# (pid=89058) If using Keras pass *_constraint arguments to layers.
# (pid=89058) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89058) Instructions for updating:
# (pid=89058) If using Keras pass *_constraint arguments to layers.
# (pid=89059) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89059) Instructions for updating:
# (pid=89059) If using Keras pass *_constraint arguments to layers.
# (pid=89059) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89059) Instructions for updating:
# (pid=89059) If using Keras pass *_constraint arguments to layers.
# (pid=89048) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89048) Instructions for updating:
# (pid=89048) If using Keras pass *_constraint arguments to layers.
# (pid=89048) WARNING:tensorflow:From /root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=89048) Instructions for updating:
# (pid=89048) If using Keras pass *_constraint arguments to layers.
# 2021-09-07 05:07:54,804	WARNING tune.py:519 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
# == Status ==<br>Memory usage on this node: 27.2/38.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 8.0/8 CPUs, 0/0 GPUs, 0.0/7.85 GiB heap, 0.0/3.93 GiB objects<br>Result logdir: /root/ray_results/grid_0<br>Number of trials: 5/5 (1 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                     </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00000</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00001</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00002</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00003</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00004</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=89057) 2021-09-07 05:07:54,838	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89057) Traceback (most recent call last):
# (pid=89057)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89057)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89057)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89057)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89057)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89057)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89057)     return method(__ray_actor, *args, **kwargs)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 136, in __init__
# (pid=89057)     Trainer.__init__(self, config, env, logger_creator)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 592, in __init__
# (pid=89057)     super().__init__(config, logger_creator)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/tune/trainable.py", line 103, in __init__
# (pid=89057)     self.setup(copy.deepcopy(self.config))
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 146, in setup
# (pid=89057)     super().setup(config)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 739, in setup
# (pid=89057)     self._init(self.config, self.env_creator)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 175, in _init
# (pid=89057)     num_workers=self.config["num_workers"])
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 827, in _make_workers
# (pid=89057)     logdir=self.logdir)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py", line 85, in __init__
# (pid=89057)     lambda p, pid: (pid, p.observation_space, p.action_space)))
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/client_mode_hook.py", line 82, in wrapper
# (pid=89057)     return func(*args, **kwargs)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 1615, in get
# (pid=89057)     object_refs, timeout=timeout)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 348, in get_objects
# (pid=89057)     object_refs, self.current_task_id, timeout_ms)
# (pid=89057)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89057)     sys.exit(1)
# (pid=89057) SystemExit: 1
# (pid=89056) 2021-09-07 05:07:54,844	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89056) Traceback (most recent call last):
# (pid=89056)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89056)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89056)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89056)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89056)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89056)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89056)     return method(__ray_actor, *args, **kwargs)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 136, in __init__
# (pid=89056)     Trainer.__init__(self, config, env, logger_creator)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 592, in __init__
# (pid=89056)     super().__init__(config, logger_creator)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/tune/trainable.py", line 103, in __init__
# (pid=89056)     self.setup(copy.deepcopy(self.config))
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 146, in setup
# (pid=89056)     super().setup(config)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 739, in setup
# (pid=89056)     self._init(self.config, self.env_creator)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 175, in _init
# (pid=89056)     num_workers=self.config["num_workers"])
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 827, in _make_workers
# (pid=89056)     logdir=self.logdir)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py", line 85, in __init__
# (pid=89056)     lambda p, pid: (pid, p.observation_space, p.action_space)))
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/client_mode_hook.py", line 82, in wrapper
# (pid=89056)     return func(*args, **kwargs)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 1615, in get
# (pid=89056)     object_refs, timeout=timeout)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 348, in get_objects
# (pid=89056)     object_refs, self.current_task_id, timeout_ms)
# (pid=89056)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89056)     sys.exit(1)
# (pid=89056) SystemExit: 1
# (pid=89059) 2021-09-07 05:07:54,849	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89059) Traceback (most recent call last):
# (pid=89059)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89059)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89059)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89059)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89059)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89059)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89059)     return method(__ray_actor, *args, **kwargs)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 584, in __init__
# (pid=89059)     seed=seed)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 1376, in _build_policy_map
# (pid=89059)     conf, merged_conf)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/policy_map.py", line 127, in create_policy
# (pid=89059)     observation_space, action_space, merged_config)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy_template.py", line 251, in __init__
# (pid=89059)     get_batch_divisibility_req=get_batch_divisibility_req,
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 367, in __init__
# (pid=89059)     auto_remove_unneeded_view_reqs=True)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 594, in _initialize_loss_from_dummy_batch
# (pid=89059)     _ = self.postprocess_trajectory(dummy_batch)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy_template.py", line 269, in postprocess_trajectory
# (pid=89059)     episode)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/postprocessing.py", line 124, in compute_gae_for_sample_batch
# (pid=89059)     last_r = policy._value(**input_dict)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/utils/tf_ops.py", line 226, in call
# (pid=89059)     ret = session_or_none.run(symbolic_out[0], feed_dict)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 956, in run
# (pid=89059)     run_metadata_ptr)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1180, in _run
# (pid=89059)     feed_dict_tensor, options, run_metadata)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1359, in _do_run
# (pid=89059)     run_metadata)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
# (pid=89059)     return fn(*args)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1348, in _run_fn
# (pid=89059)     self._extend_graph()
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1388, in _extend_graph
# (pid=89059)     tf_session.ExtendSession(self._session)
# (pid=89059)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89059)     sys.exit(1)
# (pid=89059) SystemExit: 1
# (pid=89047) 2021-09-07 05:07:54,857	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89047) Traceback (most recent call last):
# (pid=89047)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89047)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89047)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89047)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89047)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89047)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89047)     return method(__ray_actor, *args, **kwargs)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 136, in __init__
# (pid=89047)     Trainer.__init__(self, config, env, logger_creator)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 592, in __init__
# (pid=89047)     super().__init__(config, logger_creator)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/tune/trainable.py", line 103, in __init__
# (pid=89047)     self.setup(copy.deepcopy(self.config))
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 146, in setup
# (pid=89047)     super().setup(config)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 739, in setup
# (pid=89047)     self._init(self.config, self.env_creator)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 175, in _init
# (pid=89047)     num_workers=self.config["num_workers"])
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 827, in _make_workers
# (pid=89047)     logdir=self.logdir)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py", line 85, in __init__
# (pid=89047)     lambda p, pid: (pid, p.observation_space, p.action_space)))
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/client_mode_hook.py", line 82, in wrapper
# (pid=89047)     return func(*args, **kwargs)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 1615, in get
# (pid=89047)     object_refs, timeout=timeout)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 348, in get_objects
# (pid=89047)     object_refs, self.current_task_id, timeout_ms)
# (pid=89047)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89047)     sys.exit(1)
# (pid=89047) SystemExit: 1
# (pid=89060) 2021-09-07 05:07:54,868	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89060) Traceback (most recent call last):
# (pid=89060)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89060)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89060)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89060)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89060)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89060)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89060)     return method(__ray_actor, *args, **kwargs)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 136, in __init__
# (pid=89060)     Trainer.__init__(self, config, env, logger_creator)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 592, in __init__
# (pid=89060)     super().__init__(config, logger_creator)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/tune/trainable.py", line 103, in __init__
# (pid=89060)     self.setup(copy.deepcopy(self.config))
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 146, in setup
# (pid=89060)     super().setup(config)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 739, in setup
# (pid=89060)     self._init(self.config, self.env_creator)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 175, in _init
# (pid=89060)     num_workers=self.config["num_workers"])
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 827, in _make_workers
# (pid=89060)     logdir=self.logdir)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py", line 85, in __init__
# (pid=89060)     lambda p, pid: (pid, p.observation_space, p.action_space)))
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/client_mode_hook.py", line 82, in wrapper
# (pid=89060)     return func(*args, **kwargs)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 1615, in get
# (pid=89060)     object_refs, timeout=timeout)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 348, in get_objects
# (pid=89060)     object_refs, self.current_task_id, timeout_ms)
# (pid=89060)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89060)     sys.exit(1)
# (pid=89060) SystemExit: 1
# (pid=89061) 2021-09-07 05:07:54,859	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89061) Traceback (most recent call last):
# (pid=89061)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89061)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89061)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89061)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89061)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89061)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89061)     return method(__ray_actor, *args, **kwargs)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 584, in __init__
# (pid=89061)     seed=seed)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 1376, in _build_policy_map
# (pid=89061)     conf, merged_conf)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/policy_map.py", line 127, in create_policy
# (pid=89061)     observation_space, action_space, merged_config)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy_template.py", line 251, in __init__
# (pid=89061)     get_batch_divisibility_req=get_batch_divisibility_req,
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 367, in __init__
# (pid=89061)     auto_remove_unneeded_view_reqs=True)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 624, in _initialize_loss_from_dummy_batch
# (pid=89061)     loss = self._do_loss_init(train_batch)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 705, in _do_loss_init
# (pid=89061)     self._stats_fetches.update(self._stats_fn(self, train_batch))
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/ppo/ppo_tf_policy.py", line 146, in kl_and_loss_stats
# (pid=89061)     train_batch[Postprocessing.VALUE_TARGETS], policy._value_fn_out),
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/utils/tf_ops.py", line 36, in explained_variance
# (pid=89061)     _, diff_var = tf.nn.moments(y - pred, axes=[0])
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_impl.py", line 1222, in moments
# (pid=89061)     math_ops.squared_difference(y, array_ops.stop_gradient(mean)),
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_array_ops.py", line 10169, in stop_gradient
# (pid=89061)     "StopGradient", input=input, name=name)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
# (pid=89061)     op_def=op_def)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
# (pid=89061)     return func(*args, **kwargs)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
# (pid=89061)     attrs, op_def, compute_device)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3411, in _create_op_internal
# (pid=89061)     node_def = _NodeDef(op_type, name, device=None, attrs=attrs)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1548, in _NodeDef
# (pid=89061)     node_def.op = compat.as_bytes(op_type)
# (pid=89061)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89061)     sys.exit(1)
# (pid=89061) SystemExit: 1
# (pid=89058) 2021-09-07 05:07:54,856	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89058) Traceback (most recent call last):
# (pid=89058)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89058)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89058)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89058)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89058)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89058)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89058)     return method(__ray_actor, *args, **kwargs)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 584, in __init__
# (pid=89058)     seed=seed)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 1376, in _build_policy_map
# (pid=89058)     conf, merged_conf)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/policy_map.py", line 127, in create_policy
# (pid=89058)     observation_space, action_space, merged_config)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy_template.py", line 251, in __init__
# (pid=89058)     get_batch_divisibility_req=get_batch_divisibility_req,
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 367, in __init__
# (pid=89058)     auto_remove_unneeded_view_reqs=True)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 594, in _initialize_loss_from_dummy_batch
# (pid=89058)     _ = self.postprocess_trajectory(dummy_batch)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy_template.py", line 269, in postprocess_trajectory
# (pid=89058)     episode)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/postprocessing.py", line 124, in compute_gae_for_sample_batch
# (pid=89058)     last_r = policy._value(**input_dict)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/utils/tf_ops.py", line 226, in call
# (pid=89058)     ret = session_or_none.run(symbolic_out[0], feed_dict)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 956, in run
# (pid=89058)     run_metadata_ptr)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1180, in _run
# (pid=89058)     feed_dict_tensor, options, run_metadata)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1359, in _do_run
# (pid=89058)     run_metadata)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
# (pid=89058)     return fn(*args)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1350, in _run_fn
# (pid=89058)     target_list, run_metadata)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
# (pid=89058)     run_metadata)
# (pid=89058)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89058)     sys.exit(1)
# (pid=89058) SystemExit: 1
# (pid=89048) 2021-09-07 05:07:54,866	ERROR worker.py:428 -- SystemExit was raised from the worker
# (pid=89048) Traceback (most recent call last):
# (pid=89048)   File "python/ray/_raylet.pyx", line 640, in ray._raylet.task_execution_handler
# (pid=89048)   File "python/ray/_raylet.pyx", line 488, in ray._raylet.execute_task
# (pid=89048)   File "python/ray/_raylet.pyx", line 525, in ray._raylet.execute_task
# (pid=89048)   File "python/ray/_raylet.pyx", line 532, in ray._raylet.execute_task
# (pid=89048)   File "python/ray/_raylet.pyx", line 536, in ray._raylet.execute_task
# (pid=89048)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task.function_executor
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=89048)     return method(__ray_actor, *args, **kwargs)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 584, in __init__
# (pid=89048)     seed=seed)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 1376, in _build_policy_map
# (pid=89048)     conf, merged_conf)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/policy_map.py", line 127, in create_policy
# (pid=89048)     observation_space, action_space, merged_config)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy_template.py", line 251, in __init__
# (pid=89048)     get_batch_divisibility_req=get_batch_divisibility_req,
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/dynamic_tf_policy.py", line 320, in __init__
# (pid=89048)     action_dist = dist_class(dist_inputs, self.model)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/models/tf/tf_action_dist.py", line 264, in __init__
# (pid=89048)     mean, log_std = tf.split(inputs, 2, axis=1)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/ops/array_ops.py", line 1680, in split
# (pid=89048)     size_splits = ops.convert_to_tensor(num_or_size_splits)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1184, in convert_to_tensor
# (pid=89048)     return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1242, in convert_to_tensor_v2
# (pid=89048)     as_ref=False)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1297, in internal_convert_to_tensor
# (pid=89048)     ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_conversion_registry.py", line 52, in _default_conversion_function
# (pid=89048)     return constant_op.constant(value, dtype, name=name)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/constant_op.py", line 227, in constant
# (pid=89048)     allow_broadcast=True)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/constant_op.py", line 271, in _constant_impl
# (pid=89048)     name=name).outputs[0]
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
# (pid=89048)     return func(*args, **kwargs)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
# (pid=89048)     attrs, op_def, compute_device)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
# (pid=89048)     op_def=op_def)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1783, in __init__
# (pid=89048)     for i, output_type in enumerate(output_types)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1783, in <listcomp>
# (pid=89048)     for i, output_type in enumerate(output_types)
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 384, in __init__
# (pid=89048)     self._op = op
# (pid=89048)   File "/root/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 425, in sigterm_handler
# (pid=89048)     sys.exit(1)
# (pid=89048) SystemExit: 1
# (pid=89061) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (pid=89061) Quitting (on error).
# (pid=89058) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (pid=89058) Quitting (on error).
# (pid=89059) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (pid=89059) Quitting (on error).
# (pid=89048) Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# (pid=89048) Quitting (on error).
# 2021-09-07 05:07:55,077	ERROR tune.py:557 -- Trials did not complete: [PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00000, PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00001, PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00002, PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00003, PPO_TrafficLightGridBenchmarkEnv-v0_8a00f_00004]
# 2021-09-07 05:07:55,078	INFO tune.py:561 -- Total run time: 8.96 seconds (8.63 seconds for the tuning loop).
# 2021-09-07 05:07:55,079	WARNING tune.py:566 -- Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
# == Status ==<br>Memory usage on this node: 25.3/38.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/7.85 GiB heap, 0.0/3.93 GiB objects<br>Result logdir: /root/ray_results/grid_0<br>Number of trials: 5/5 (5 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                                     </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8f577_00000</td><td>PENDING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8f577_00001</td><td>PENDING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8f577_00002</td><td>PENDING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8f577_00003</td><td>PENDING </td><td>     </td></tr>
# <tr><td>PPO_TrafficLightGridBenchmarkEnv-v0_8f577_00004</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
